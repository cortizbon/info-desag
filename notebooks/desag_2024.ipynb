# %%
import pandas as pd
import json
import numpy as np
import re

# %%
#df_2019 = pd.read_excel('2019.xlsx')
df_2024 = pd.read_excel('2024.xlsx')
#df_2020 = pd.read_excel('2020.xlsx', sheet_name=1)

# %%
def get_row_with_column_names(path, sheetname=0):
    renglon = 0
    df = pd.read_excel(path,
                          sheet_name=sheetname,
                          skiprows=renglon,
                          nrows=10)
    while "CONCEPTO" not in df.columns:

        renglon += 1
        df = pd.read_excel(path,
                          sheet_name=sheetname,
                          skiprows=renglon,
                          nrows=10)
    return renglon

def reverse_dictio(dictio):
  reversed_entities = {}
  for key, value in dic_entities.items():
    reversed_entities[value] = key

  return reversed_entities

# aplicar diccionario de entidades
# filtro tres columnas
# aplicar función con apply
# reversed entities

# ffill concepto
# aplicar diccionario de sectores
# ffill number
# eliminar seccion
# rename columns

dic = {'A.  PRESUPUESTO DE FUNCIONAMIENTO': 'FUNCIONAMIENTO',
 'B.  PRESUPUESTO DE SERVICIO DE LA DEUDA PUBLICA': 'DEUDA',
'B.  PRESUPUESTO DE SERVICIO DE LA DEUDA PÚBLICA': 'DEUDA',

 'C.  PRESUPUESTO DE INVERSION': 'INVERSION'}

with open("dic_entities.json", 'r') as de:
  dic_entities = json.load(de)

with open("dic_sector.json", 'r') as de:
  dic_sector = json.load(de)

with open("dic_sec_ents.json", 'r') as de:
  dic_sec_ents = json.load(de)

with open("dic_tipo_gasto.json", 'r') as de:
  dic_tipo_gasto = json.load(de)

dic_cuentas = {0:'subproyecto',
               1:'proyecto',
               2:'subcuenta',
               3:'cuenta'}

# %%
dic_sector_rev = reverse_dictio(dic_sector)

# %%
renglon = get_row_with_column_names('2024.xlsx')

df = pd.read_excel('2024.xlsx',
                     sheet_name=0, skiprows=renglon)
#df = df.iloc[1630: 2322]

df.columns = [s.strip() for s in df.columns]

df = df[~(df['CTA  \nPROG'].isna()) | ~(df['CONCEPTO'].isna())]



rev_entities = reverse_dictio(dic_entities)

try:
  df.drop(columns=['Unnamed: 0', 'Unnamed: 1'], inplace=True)
except:
  print('Error')

df['CONCEPTO'] = df['CONCEPTO'].str.capitalize().str.strip()
df['CONCEPTO'] = df['CONCEPTO'].fillna(method='ffill')
df['Código de entidad'] = df['CONCEPTO'].map(rev_entities)
df['Tipo de gasto'] = df['CONCEPTO'].str.extract(pat="([ABC]{1}\..*)")[0]

# %%
df.reset_index(drop=True, inplace=True)

# %%
for idx, row in df.iterrows():
  cuenta = row['CTA  \nPROG']
  subcuenta = row['SUBC\nSUBP']
  proyecto = row['OBJG PROY']
  subproyecto = row['ORD  \nSPRY']
  concepto = row['CONCEPTO']

  if not pd.isna(subcuenta) and pd.isna(proyecto) and not pd.isna(subproyecto):
    ls = concepto.split('/')
    a = ls[0]
    b = ls[1]
    df.loc[idx, 'OBJG PROY'] = ls[0]
    df.loc[idx, 'ORD  \nSPRY'] = ls[1]

# %%
df['seccion'] = df['CONCEPTO'].str.extract(pat="(^Sección:[\s]+\d{4})")[0]
df['seccion'].ffill(inplace=True)

df['Código de entidad'] = df['seccion'].str.extract(pat="(\d{4}$)").astype("Int64").astype(str)
df['Entidad'] = df['Código de entidad'].map(dic_entities)
df['Código de sector'] = df['Código de entidad'].map(dic_sec_ents).astype("Int64").astype(str)
df['Sector'] = df['Código de sector'].map(dic_sector)

dic_cuentas = {0:'subproyecto',
               1:'proyecto',
               2:'subcuenta',
               3:'cuenta'}

df['nans'] = df[['CTA  \nPROG', 'SUBC\nSUBP', 'OBJG PROY', 'ORD  \nSPRY']].isna().sum(axis=1)
df['Tipo de cuenta'] = df['nans'].map(dic_cuentas)

df['Entidad'].fillna(method='ffill', inplace=True)
df['Código de sector'].fillna(method='ffill', inplace=True)

df['Unidad'] = df['CONCEPTO'].str.extract(pat="(Unidad: \d{6})")[0]
df['Código de unidad'] = df['Unidad'].str.extract(pat="(\d{6})")[0]
print(df.columns)
df = df[df['REC'].isna()]

def funcion(row):
  if not pd.isna(row['Tipo de cuenta']):
    return row['CONCEPTO']
  else:
    return np.nan

df['Nombre de cuenta'] = df.apply(funcion, axis=1)

dic_unidades = {}
df.reset_index(drop=True, inplace=True)
for idx, row in df.iterrows():
  if not pd.isna(row['Unidad']):
    df.loc[idx, 'Unidad'] = df.loc[idx + 1, 'CONCEPTO']

df['Tipo de gasto'].ffill(inplace=True)
#df['Unidad'].ffill(inplace=True)
#df['Código de unidad'].ffill(inplace=True)

#df['TOTAL'] = df['TOTAL'].str.replace(',','_').astype(float)
df['Cuenta_n'] = df['CTA  \nPROG']
df.drop(columns='REC', inplace=True)

dic_cuentas = df[df['Tipo de cuenta'] == 'cuenta'][['CTA  \nPROG', 'CONCEPTO']].drop_duplicates().set_index('CTA  \nPROG').to_dict()['CONCEPTO']
df['CTA  \nPROG'] = df['CTA  \nPROG'].map(dic_cuentas)
df['seleccion'] = None
# Out:
# Index(['CTA  \nPROG', 'SUBC\nSUBP', 'OBJG PROY', 'ORD  \nSPRY', 'REC',
#        'CONCEPTO', 'APORTE\nNACIONAL', 'RECURSOS \nPROPIOS', 'TOTAL',
#        'Código de entidad', 'Tipo de gasto', 'seccion', 'Entidad',
#        'Código de sector', 'Sector', 'nans', 'Tipo de cuenta', 'Unidad',
#        'Código de unidad'],
#       dtype='object')
# <ipython-input-394-4ea06d68a728>:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Nombre de cuenta'] = df.apply(funcion, axis=1)

# %%
dic_unidades = dict(df[['Código de unidad', 'Unidad']].drop_duplicates().set_index('Código de unidad').to_records())

with open('dic_unidades.json', 'w') as f:
  json.dump(dic_unidades, f)

# %%
df['Tipo de gasto'] = df['Tipo de gasto'].str.split(' ').str[1].str.capitalize()
df.loc[df['Tipo de gasto'] == 'Servicio', 'Tipo de gasto'] = 'Deuda'

# %%
df['Subcuenta_n'] = df['SUBC\nSUBP']
df['Objeto_n'] = df['OBJG PROY']
df['Ordinal_n'] = df['ORD  \nSPRY']

# %%
df.reset_index(drop=True, inplace=True)

# %%
for value in df['CTA  \nPROG'].dropna().unique():


  # slice por cuenta
  filtro = df[df['CTA  \nPROG'] == value]
  dic_subcuenta = filtro[filtro['Tipo de cuenta'] == 'subcuenta'][['SUBC\nSUBP', 'CONCEPTO']].dropna().set_index('SUBC\nSUBP').to_dict()['CONCEPTO']
  df.loc[filtro.index, 'SUBC\nSUBP'] = filtro['SUBC\nSUBP'].map(dic_subcuenta)
  df.loc[filtro.index, 'seleccion'] = filtro['nans'].min()
  if value == 'Infraestructura de transporte férreo':
    print(dic_subcuenta)


  for value2 in filtro['SUBC\nSUBP'].dropna().unique():

    filtro2 = filtro[filtro['SUBC\nSUBP'] == value2]
    dic_proyecto = filtro2[filtro2['Tipo de cuenta'] == 'proyecto'][['OBJG PROY', 'CONCEPTO']].dropna().set_index('OBJG PROY').to_dict()['CONCEPTO']
    if value2 == 'Intersubsectorial transporte':
      print(dic_proyecto)

    try:
      df.loc[filtro2.index, 'OBJG PROY'] = filtro2['OBJG PROY'].map(dic_proyecto)
    except:
      print(value, value2)
      #print(filtro2['OBJG PROY'].map(dic_proyecto))




    df.loc[filtro2.index, 'seleccion'] = filtro2['nans'].min()
    for value3 in filtro2['OBJG PROY'].dropna().unique():

      filtro3 = filtro2[filtro2['OBJG PROY'] == value3]
      dic_subproyecto = filtro3[filtro3['Tipo de cuenta'] == 'subproyecto'][['ORD  \nSPRY', 'CONCEPTO']].dropna().set_index('ORD  \nSPRY').to_dict()['CONCEPTO']
      df.loc[filtro3.index, 'ORD  \nSPRY'] = filtro3['ORD  \nSPRY'].map(dic_subproyecto)
      df.loc[filtro3.index, 'seleccion'] = filtro3['nans'].min()
# Out:
# {600.0: 'Intersubsectorial transporte'}

# %%
df.columns
# Out:
# Index(['CTA  \nPROG', 'SUBC\nSUBP', 'OBJG PROY', 'ORD  \nSPRY', 'CONCEPTO',
#        'APORTE\nNACIONAL', 'RECURSOS \nPROPIOS', 'TOTAL', 'Código de entidad',
#        'Tipo de gasto', 'seccion', 'Entidad', 'Código de sector', 'Sector',
#        'nans', 'Tipo de cuenta', 'Unidad', 'Código de unidad',
#        'Nombre de cuenta', 'Cuenta_n', 'seleccion', 'Subcuenta_n', 'Objeto_n',
#        'Ordinal_n'],
#       dtype='object')

# %%
df.loc[(df['OBJG PROY'].str.contains('Recuperación de equipos de cómputo').fillna(False)) &(df['ORD  \nSPRY'].notna()), 'TOTAL'] = 2892575250.0
df.loc[(df['OBJG PROY'].str.contains('Recuperación de equipos de cómputo').fillna(False)) &(df['ORD  \nSPRY'].notna()), 'RECURSOS \nPROPIOS'] = 2892575250.0

# %%
df = df[df['seleccion'] == df['nans']]

# %%
df = (df
      .drop(columns=['seccion', 'nans', 'Tipo de cuenta', 'Nombre de cuenta', 'seleccion', 'CONCEPTO'])
      .rename(columns={'CTA  \nPROG':'Cuenta',
               'SUBC\nSUBP': 'Subcuenta',
               'OBJG PROY': 'Objeto',
               'ORD  \nSPRY': 'Ordinal',
               'APORTE\nNACIONAL': 'Aporte nacional',
               'RECURSOS \nPROPIOS': 'Recursos propios'}))

# %%
df.reset_index(drop=True, inplace=True)

# %%
df['TOTAL'].sum()
# Out:
# 502596833224189.0

# %%
gastos = pd.read_csv('gastos.csv')
gastos = gastos[gastos['Año'] == 2024]
#TIC = gastos[(gastos['Sector'] == 'Tecnologías de la información y las comunicaciones') & (gastos['Tipo de gasto'] == 'Inversión')]

# %%
gastos.groupby('Sector')['apropiacion_corrientes'].sum() - df.groupby('Sector')['TOTAL'].sum()
# Out:
# Sector
# Agricultura y desarrollo rural                                      0.0
# Ambiente y desarrollo sostenible                                    0.0
# Ciencia, tecnología e innovación                                    0.0
# Comercio, industria y turismo                                       0.0
# Congreso de la república                                            0.0
# Defensa y policía                                                   0.0
# Deporte y recreación                                                0.0
# Educación                                                           0.0
# Empleo público                                                      0.0
# Fiscalía                                                            0.0
# Hacienda                                                            0.0
# Igualdad y equidad                                                  0.0
# Inclusión social y reconciliación                                   0.0
# Información estadistíca                                             0.0
# Inteligencia                                                        0.0
# Interior                                                            0.0
# Justicia y el derecho                                               0.0
# Minas y energía                                                     0.0
# Ministerio de las culturas, las artes y los saberes ancestrales     0.0
# Organismos de control                                               0.0
# Planeación                                                          0.0
# Presidencia de la república                                         0.0
# Rama judicial                                                       0.0
# Registraduría                                                       0.0
# Relaciones exteriores                                               0.0
# Salud y protección social                                           0.0
# Servicio de la deuda pública nacional                               0.0
# Sistema integral de verdad, justicia, reparación y no repetición    0.0
# Tecnologías de la información y las comunicaciones                  0.0
# Trabajo                                                             0.0
# Transporte                                                          0.0
# Vivienda, ciudad y territorio                                       0.0
# dtype: float64

# %%
df.to_csv('datos_desag_2024_cuentas.csv', index=False)

# %%
df.columns
# Out:
# Index(['Cuenta', 'Subcuenta', 'Objeto', 'Ordinal', 'Aporte nacional',
#        'Recursos propios', 'TOTAL', 'Código de entidad', 'Tipo de gasto',
#        'Entidad', 'Código de sector', 'Sector', 'Unidad', 'Código de unidad',
#        'Cuenta_n', 'Subcuenta_n', 'Objeto_n', 'Ordinal_n'],
#       dtype='object')

# %%
nvls = df[['Cuenta', 'Subcuenta', 'Objeto', 'Ordinal', 'Cuenta_n', 'Subcuenta_n', 'Objeto_n', 'Ordinal_n']].drop_duplicates()

# %%
nvls
# Out:
#                                                  Cuenta  \
# 8                                    Gastos de personal
# 9                                    Gastos de personal
# 10                                   Gastos de personal
# 11                   Adquisición de bienes  y servicios
# 14                            Transferencias corrientes
# ...                                                 ...
# 7930  Fortalecimiento de la gestión y dirección del ...
# 7954  Cierre de brechas para el goce efectivo de der...
# 7958  Cierre de brechas para el goce efectivo de der...
# 7963  Fortalecimiento de la gestión y dirección del ...
# 7965  Fortalecimiento de la gestión y dirección del ...
#
#                                          Subcuenta  \
# 8                    Planta de personal permanente
# 9                    Planta de personal permanente
# 10                   Planta de personal permanente
# 11                                             NaN
# 14    A gobiernos y organizaciones internacionales
# ...                                            ...
# 7930           Intersubsectorial desarrollo social
# 7954           Intersubsectorial desarrollo social
# 7958           Intersubsectorial desarrollo social
# 7963           Intersubsectorial desarrollo social
# 7965           Intersubsectorial desarrollo social
#
#                                                  Objeto  \
# 8                                               Salario
# 9                 Contribuciones inherentes a la nómina
# 10    Remuneraciones no constitutivas de factor sala...
# 11                                                  NaN
# 14                     A organizaciones internacionales
# ...                                                 ...
# 7930  Optimización de las capacidades institucionale...
# 7954  Mejoramiento de herramientas y orientaciones p...
# 7958  Mejoramiento de los procesos de atención para ...
# 7963  Fortalecimiento de la gestión institucional de...
# 7965  Optimización de las capacidades institucionale...
#
#                                                 Ordinal  Cuenta_n  \
# 8                                                   NaN       1.0
# 9                                                   NaN       1.0
# 10                                                  NaN       1.0
# 11                                                  NaN       2.0
# 14                                                  NaN       3.0
# ...                                                 ...       ...
# 7930  5. convergencia regional / b. entidades públic...    4699.0
# 7954  7. actores diferenciales para el cambio / 1. u...    4601.0
# 7958  7. actores diferenciales para el cambio / 1. u...    4601.0
# 7963  7. actores diferenciales para el cambio / 1. u...    4699.0
# 7965  7. actores diferenciales para el cambio / 1. u...    4699.0
#
#       Subcuenta_n Objeto_n Ordinal_n
# 8             1.0      1.0       NaN
# 9             1.0      2.0       NaN
# 10            1.0      3.0       NaN
# 11            NaN      NaN       NaN
# 14            2.0      2.0       NaN
# ...           ...      ...       ...
# 7930       1500.0      2.0   53105b
# 7954       1500.0      1.0    707010
# 7958       1500.0      2.0    707010
# 7963       1500.0      1.0    707010
# 7965       1500.0      2.0    707010
#
# [1226 rows x 8 columns]

# %%
dic_total = {}
for key, value in dic_cuentas.items():
  dic_subcuentas = {}
  filtro = nvls[nvls['Cuenta_n'] == key]
  lista_subcuentas = dict(filtro[['Subcuenta_n', 'Subcuenta']].dropna().set_index('Subcuenta_n').to_records())
  if len(lista_subcuentas.values()) > 0:
    print('Subcuentas', lista_subcuentas)
    for key_sub, subcuenta in lista_subcuentas.items():
      filtro_subcuentas = filtro[filtro['Subcuenta_n'] == key_sub]
      lista_objetos = dict(filtro_subcuentas[['Objeto_n', 'Objeto']].dropna().set_index('Objeto_n').to_records())
      if len(lista_objetos.values()) > 0:
        print('Objetos', lista_objetos)
        dic_objetos = {}
        for key_obj, objeto in lista_objetos.items():
          filtro_objetos = filtro_subcuentas[filtro_subcuentas['Objeto_n'] == key_obj]
          lista_ordinal = dict(filtro_objetos[['Ordinal_n', 'Ordinal']].dropna().set_index('Ordinal_n').to_records())
          if len(lista_ordinal.values()) > 0:
            print("Ordinal", lista_ordinal)
          dic_objetos[key_obj] = [objeto, lista_ordinal]
      dic_subcuentas[key_sub] = [subcuenta, dic_objetos]
  dic_total[key] = [value, dic_subcuentas]
# Out:
# Subcuentas {1.0: 'Planta de personal permanente', 2.0: 'Personal supernumerario y planta temporal'}
# Objetos {1.0: 'Salario', 2.0: 'Contribuciones inherentes a la nómina', 3.0: 'Remuneraciones no constitutivas de factor salarial', 4.0: 'Otros gastos de personal - distribución previo concepto dgppn', 5.0: 'Personal extranjero en consulados y embajadas (local)'}
# Objetos {4.0: 'Otros gastos de personal - distribución previo concepto dgppn', 1.0: 'Salario', 2.0: 'Contribuciones inherentes a la nómina', 3.0: 'Remuneraciones no constitutivas de factor salarial'}
# Subcuentas {2.0: 'A gobiernos y organizaciones internacionales', 3.0: 'A entidades del gobierno', 4.0: 'Prestaciones para cubrir riesgos sociales', 8.0: 'Becas y otros beneficios de educación', 10.0: 'Sentencias y conciliaciones', 6.0: 'A instituciones sin ánimo de lucro que sirven a los hogares', 1.0: 'Subvenciones', 11.0: 'A empresas diferentes de subvenciones', 9.0: 'A productores de mercado que distribuyen directamente a los hogares', 12.0: 'A los hogares diferentes de prestaciones sociales'}
# Objetos {2.0: 'A organizaciones internacionales'}
# Objetos {1.0: 'A órganos del pgn', 4.0: 'A otras entidades del gobierno general', 2.0: 'A entidades territoriales distintas al sistema general de participaciones', 3.0: 'A esquemas asociativos', 5.0: 'Sistema general de participaciones'}
# Ordinal {'999': 'Otras transferencias - distribución previo concepto dgppn', '051': 'Fondo de programas especiales para la paz', '052': 'Plan de promoción de colombia en el exterior', '077': 'Transferencias para la estrategia de interacción y diálogo permanente entre las autoridades de orden territorial, gobierno nacional y los ciudadanos', '001': 'Fondo de programas especiales para la paz: programa de reintegración social y económica', '056': 'Deportación a extranjeros', '028': 'Fondo para la lucha contra las drogas', '063': 'Fondo para la rehabilitación, inversión social y lucha contra el crimen organizado', '054': 'Fondo para los notarios de insuficientes ingresos. decreto 1672 de 1997', '017': 'Atención rehabilitación al recluso', '018': 'Implementación y desarrollo del sistema integral de tratamiento progresivo penitenciario', '019': 'Servicio postpenitenciario ley 65 de 1993', '078': 'Defensa de los intereses del estado en controversias internacionales', '025': 'Fondo de compensación interministerial', '026': 'Gastos inherentes a la intervención administrativa parágrafo  3,  art. 10, decreto 4334 de 2008, art. 1   decreto 1761 de 2009', '074': 'Atención de procesos judiciales y reclamaciones administrativas del extinto das o su fondo rotatorio. art. 238 ley 1753 de 2015 - pnd', '075': 'Pagos beneficiarios fundación san juan de dios derivados del fallo su-484 2008 corte constitucional', '087': 'Comité autónomo de la regla fiscal - carf art. 61. ley 2155 de 2021', '023': 'Programa de desmovilización y sometimiento (decreto 128 de 2003 y 965 de 2020)', '086': 'Fondo de defensa técnica y especializada de los miembros de la fuerza pública', '024': 'Transferencia al hospital militar central', '009': 'Programa de protección a personas que se encuentran en situación de riesgo contra su vida, integridad, seguridad o libertad, por causas relacionadas con la violencia en colombia', '020': 'Fondo de fomento agropecuario decreto ley  1279 de 1994', '067': 'Desarrollo de funciones de apoyo al sector agropecuario en ciencia, tecnología e innovación a cargo de corpoica a nivel nacional. ley 1731 de 2014', '085': 'Fondo nacional de emergencias sanitarias y fitosanitarias del instituto colombiano agropecuario - ica', '029': 'Decisiones judiciales en contra de la nación en la liquidación de entidades públicas del orden nacional', '070': 'Gastos de administración de pensiones, nómina, archivo y otras actividades inherentes decreto 4986 de 2007, decreto 2721 de 2008 y decreto 2601 de 2009', '002': 'Transferir a la upme ley 143 de 1994', '042': 'Educación de niñas y niños en situaciones especiales', '050': 'Mejoramiento de la enseñanza de las lenguas extranjeras en educación básica', '004': 'A la comisión de regulación de comunicaciones (crc). artículo 20 ley 1978 de 2019', '011': 'Transferir a la agencia nacional del espectro articulo 31 ley 1341 de 2009 y articulo 6o. del decreto 4169 de 2011', '012': 'Transferir a la superintendencia de industria y comercio decretos 1130 y 1620 de 1999 y 2003.  leyes 1341 y 1369 de 2009', '083': 'Apoyo a actividades del mintic. art 22 ley 1978 de 2019', '088': 'Computadores para educar - cpe (art. 39 ley  1341 de 2009)', '053': 'Fondo de protección de justicia. decreto 1890 de 1999 y decreto 200 de 2003', '007': 'Defensoría pública (ley 24 de 1992)', '008': 'Fondo para la defensa de los derechos e intereses colectivos -ley 472 de 1998.', '061': 'Fondo especial comisión nacional de búsqueda (art. 18 ley 971 de 2005)', '068': 'Comisión de búsqueda de personas desaparecidas ley 589 de 2000', '006': 'Fondo de capacitación y publicaciones contraloría general de la república - decreto 267 de 2000 y ley 1807 de 2016', '079': 'Fondo para la modernización, descongestión y bienestar de la administración de justicia', '066': 'Congreso de medicina legal y ciencias forenses', '021': 'Fondo de compensación ambiental distribución comité fondo-ministerio del medio ambiente artículo 24 ley 344 de 1996.', '034': 'Fortalecim ...
# Ordinal {'073': 'Operación y funcionamiento del centro de altos estudios legislativos jorge aurelio iragorri hormaza (cael), creado por el artículo 6° de la ley 2165 de 2021', '036': 'Fondo colombia en paz (fcp) - decreto 691 de 2017', '066': 'Fondo mujer emprende. decreto ley 810 de 2020 y ley 2069 de 2020.', '013': 'Atención de desastres y emergencias en el territorio nacional -fondo nacional de gestión del riesgo de desastres', '063': 'Fondo empresarial - ley 812 de 2003', '017': 'A universidades para funcionamiento ley 30 de 1992 artículo 86', '015': 'Fondo nacional de emergencias', '050': 'Transferencia a la sociedad fiduciaria de desarrollo agropecuario s.a. fiduagraria - patrimonio autónomo de remanentes - incoder en liquidación', '070': 'Fondo de fomento para las mujeres rurales -fommur, ley 731 de 2002', '018': 'Tribunales de ética médica, odontología y enfermería', '052': 'Aseguramiento, reclamaciones y servicios integrales en salud, (ley 100 de 1993 y decreto 780 de 2016)', '006': 'Transferencias de excedentes financieros a la nación (art. 16 eop)', '009': 'Ley 37 de 1987 - aportes conservatorio del tolima.', '031': 'Cuerpos consultivos', '037': 'Colegio boyacá (decreto 3176 de 2005 artículo 2)', '059': 'Recursos para transferir a instituciones de educación superior públicas, artículo 142 de la ley 1819 de 2016.', '061': 'A  instituciones  de educación superior públicas – descuento de matrículas por votaciones (ley 2019 de 2020)', '064': 'A instituciones de educación superior públicas', '065': 'Órganos asesores y consultores de la calidad en educación superior', '001': 'Transferencias bienestar universitario (ley 30 de 1992)', '008': 'Ley 30 de 1992, articulo 87 - distribución cesu', '016': 'A institutos de investigación ley 99 de 1993', '002': 'Actividades de promoción y desarrollo de la cultura. ley  397 de 1997', '069': 'Fondo para la promoción del patrimonio, la cultura, las artes y la creatividad -foncultura- ley 2070 de 2020', '028': 'Recursos a bancoldex', '029': 'Recursos al fondo fílmico colombia (ffc) - ley 1556 de 2012', '019': 'Consejo nacional del trabajo social', '035': 'Fondo para la participación ciudadana y el fortalecimiento de la democracia. articulo 96 ley 1757 de 2015', '060': 'Pago de aportes sobre los voluntarios acreditados y activos del subsistema nacional de primera respuesta afiliados al sgrl - decreto 1809 de 2020', '062': 'Apoyo comité interinstitucional de alertas tempranas ciat sentencia t-025 de 2004.', '048': 'Escuela nacional del deporte - art. 51 decreto 2845 de 1984', '072': 'Comité de seguimiento y monitoreo a la implementación de las recomendaciones de la cev – artículo 32 del decreto ley 588 de 2017', '074': 'Fondo para la superación de brechas de desigualdad poblacional e inequidad territorial (art. 72- ley 2294/2023'}
# Ordinal {'008': 'Departamento archipiélago de san andrés, providencia y santa catalina (ley 1a. de 1972)', '010': 'Fondo de desarrollo para la guajira - fondeg, artículo 19 ley 677 de 2001', '012': 'Recursos a los municipios con resguardos indígenas art. 24 ley 44 de 1990, art. 184 ley 223 de 1995', '016': 'Recursos a los municipios con territorios colectivos de comunidades negras. artículo 255 ley 1753 de 2015', '017': 'Seguimiento, actualización de calculos actuariales, diseño de administración financiera del pasivo pensional de las entidades territoriales (artículo 48 de la ley 863 de 2003)', '029': 'Participación iva - departamento archipiélago de san andrés providencia y santa catalina', '030': 'Participación iva - departamento del amazonas', '031': 'Participación iva - departamento del arauca', '032': 'Participación iva - departamento del casanare', '033': 'Participación iva - departamento del guainía', '034': 'Participación iva - departamento del guaviare', '035': 'Participación iva - departamento del putumayo', '036': 'Participación iva - departamento del vaupés', '037': 'Participación iva - departamento del vichada', '002': 'Apoyo a programas de desarrollo de la salud ley 100 de 1993', '003': 'Asistencia ancianos, niños adoptivos y población desprotegida ley 1251 de 2002', '006': 'Suministro de medicamentos de leishmaniasis', '013': 'Aportes a programas de prevención y control de enfermedades transmitidas por vectores', '007': 'Prevención de la farmacodependencia y de medicamentos de control especial', '011': 'Recursos de oro y platino para los municipios productores decreto 2173 de 1992', '005': 'Recursos a municipios, espectáculos públicos art. 7 de la ley 1493 del 26 de diciembre de 2011', '023': 'Distribución de recursos impuesto nacional al consumo sobre los servicios de telefonía móvil - sector cultura, art 201 ley 1819 de 2016', '014': 'Pueblo nukak maku (artículo 35 decreto 1953 de 2014)', '024': 'Organización y funcionamiento departamento del amazonas', '025': 'Organización y funcionamiento departamento del guainía', '026': 'Organización y funcionamiento departamento del guaviare', '027': 'Organización y funcionamiento departamento del vaupés', '028': 'Organización y funcionamiento departamento del vichada'}
# Ordinal {'001': 'Transferencia a la región metropolitana bogotá - cundinamarca. art. 42, ley 2199 de 2022'}
# Ordinal {'003': 'Participación para propósito general', '004': 'Municipios de la ribera del río magdalena - asignaciones especiales', '005': 'Programas de alimentación escolar - asignaciones especiales', '006': 'Fonpet - asignaciones especiales', '007': 'Resguardos indígenas - asignaciones especiales', '002': 'Participación para salud - distribución previo concepto dnp', '001': 'Participación para educación - distribución previo concepto dnp', '008': 'Agua potable y saneamiento básico'}
# Objetos {2.0: 'Prestaciones sociales relacionadas con el empleo', 1.0: 'Prestaciones de asistencia social', 3.0: 'Prestaciones sociales asumidas por el gobierno'}
# Ordinal {'012': 'Incapacidades y licencias de maternidad y paternidad (no de pensiones)', '001': 'Mesadas pensionales (de pensiones)', '002': 'Cuotas partes pensionales (de pensiones)', '004': 'Bonos pensionales (de pensiones)', '091': 'Fondo nacional pasivo pensional y prestacional de la electrificadora del caribe s.a e.s.p - foneca (de pensiones)', '085': 'Compensación por muerte', '014': 'Auxilio funerario (otras prestaciones de jubilación)', '089': 'Prestaciones económicas fonprenor - ley 1668 de 1997 (otras prestaciones de jubilación)', '023': 'Indemnización por disminución de la capacidad psicofísica (no de pensiones)', '029': 'Planes complementarios de salud (no de pensiones).', '024': 'Transferir al fondo de solidaridad de la caja de vivienda militar y de policía. numeral 5 parágrafo 2 articulo 1 ley 1305 de 2009 (no de pensiones)', '015': 'Aporte previsión social servicios médicos (otras prestaciones de jubilación)', '013': 'Asignaciones de retiro (no de pensiones)', '037': 'Bienestar social afiliados de la caja de retiro de las fuerzas militares y la caja de sueldos de retiro de la policía nacional, decretos 2002 y 2003 de 1984 (no de pensiones)', '084': 'Auxilio mutuo (no de préstamos) (no de pensiones)', '009': 'Obligaciones convencionales pensionados del idema (otras prestaciones de jubilación)', '080': 'Mesadas pensionales del idema (de pensiones)', '022': 'Programas de vivienda y otros (no de pensiones)', '027': 'Aportes convencionales a salud y auxilio funerarios fondo pasivo social empresa puertos de colombia (otras prestaciones de jubilación)', '017': 'Bienestar social del pensionado (otras prestaciones de jubilación)', '094': 'Auxilio funerario (otras prestaciones de jubilación)', '095': 'Indemnización sustitutiva (otras prestaciones de jubilación)', '019': 'Promoción y prevención en salud (no de pensiones)', '020': 'Servicios médicos asistenciales (no de pensiones)', '021': 'Servicios médicos convencionales (no de pensiones)', '010': 'Aportes previsión pensiones vejez jubilados (de pensiones)', '007': 'Fondo nacional de prestaciones sociales del magisterio (de pensiones)', '031': 'Fondo nacional de prestaciones sociales del magisterio (no de pensiones)', '083': 'Recursos para transferir al fondo nacional de prestaciones sociales del magisterio, previa revisión faltante de cesantías', '036': 'Programa de salud ocupacional (no de pensiones)', '016': 'Servicios médicos, educativos, recreativos, y culturales para funcionarios de la contraloría general de la república (art. 90 y 91 ley 106 de 1993) (no de pensiones)', '077': 'Mesadas pensionales - zonas francas (de pensiones)', '078': 'Mesadas pensionales concesión de salinas (de pensiones)', '082': 'Mesadas pensionales de la superintendencia de sociedades a través del fopep (de pensiones)', '006': 'Fondo prestaciones de los pensionados de las empresas productoras de metales del chocó ley 50 de 1990 (de pensiones)', '038': 'Fondo de pensiones públicas de nivel nacional - pensiones superintendencia de valores (de pensiones)', '039': 'Fondo de pensiones públicas del nivel nacional - cajanal pensiones (de pensiones)', '040': 'Fondo de pensiones públicas del nivel nacional - carbocol (de pensiones)', '041': 'Fondo de pensiones públicas del nivel nacional - pensiones caja de crédito agrario industrial y minero (de pensiones)', '042': 'Fondo de pensiones públicas del nivel nacional - pensiones fonprenor (de pensiones)', '043': 'Fondo de pensiones públicas del nivel nacional - pensiones superindustria y comercio (de pensiones)', '044': 'Fondo de pensiones públicas del nivel nacional - pensiones supersociedades (de pensiones)', '045': 'Fondo de pensiones públicas del nivel nacional -pensiones cvc - epsa (de pensiones)', '046': 'Fondo de pensiones públicas del nivel nacional-pensiones fondo pasivo social empresa puertos de colombia (de pensiones)', '047': 'Fondo de pensiones públicas del nivel nacional - pensiones fondo nacional de caminos vecinales (de pensiones)', '048 ...
# Ordinal {'012': 'Atención integral a la población desplazada en cumplimiento de la sentencia t-025 de 2004 (no de pensiones)', '011': 'Implementación del sistema integral de salud en el sistema penitenciario (no de pensiones)', '014': 'Alimentación para internos', '006': 'Derechos de los soldados cuando reciben lesiones permanentes, literal f, art. 40, ley 48 de 1993 (no de pensiones)', '007': 'Subsidio veteranos guerra de korea y conflicto con el perú. ley 683 de 2001 (no de pensiones)', '001': 'Mesadas pensionales enfermos de lepra (ley 148 de 1961) (de pensiones)', '008': 'Campañas control lepra (ley 148 de 1961 y ley 380 de 1997) (no de pensiones)', '009': 'Programa atención áreas marginadas y población dispersa (ley 100 de 1993) (no de pensiones)', '019': 'Atencion en salud a poblacion inimputable por trastorno mental (ley 65 de 1993) (no de pensiones)', '002': 'Transferir a colpensiones – administradora de beneficios económicos periódicos (ley 1328 de 2009 y decreto 604 de 2013 (otras prestaciones de jubilación)'}
# Ordinal {'001': 'Fondo nacional de pensiones de las entidades territoriales ley 549 de 1999 (de pensiones)', '007': 'Pagos excepcionales de extrabajadores de la fundación san juan de dios (de pensiones)', '009': 'Prestaciones del sector salud (ley 715 de 2001) (de pensiones)', '002': 'Prestaciones convencionales pensionados puertos de colombia (otras prestaciones de jubilación)', '003': 'Transferir obligaciones laborales reconocidas insolutas  empresas sociales del estado creadas por el decreto 1750 de 2003 (no de pensiones)', '006': 'Concurrencia nación pasivo pensional leyes 1151 de 2007 y 1371 de 2009 (de pensiones)', '004': 'Financiación pensiones régimen de prima media con prestación definida colpensiones ley 1151 de 2007 (de pensiones)', '005': 'Otros recursos para seguridad social', '011': 'Prestación humanitaria periódica artículo 2.2.9.5.7 decreto 600 de 2017 (no de pensiones)'}
# Objetos {1.0: 'Becas y otros beneficios de educación'}
# Ordinal {'002': 'Transferencia convenios icetex', '001': 'Créditos educativos de excelencia'}
# Objetos {1.0: 'A instituciones sin ánimo de lucro que sirven a los hogares'}
# Ordinal {'005': 'Asociación colombiana de universidades -ascun-', '001': 'Fortalecimiento de las asociaciones y ligas de consumidores (ley 73 de 1981 y decreto 1320 de 1982)', '002': 'Programas de rehabilitación para adultos ciegos - convenio con el centro de rehabilitación para adultos ciegos -crac-', '017': 'Cuerpos consultivos', '015': 'Actividades de promoción y desarrollo de la cultura', '012': 'Fortalecimiento a los procesos organizativos y de concertación de las comunidades negras, afrocolombianas, raizales y palenqueras', '013': 'Fortalecimiento a los procesos organizativos y de concertación de las comunidades indígenas, minorías y rom', '014': 'Fortalecimiento institucional de la mesa permanente de concertación con los pueblos y organizaciones indígenas - decreto 1397 de 1996', '008': 'Centro internacional de física (decreto 267 de 1984)', '009': 'Centro internacional de investigaciones médicas - cideim (decreto 578 de 1990)'}
# Objetos {4.0: 'A empresas privadas no financieras', 2.0: 'A empresas  públicas no financieras', 1.0: 'A empresas  públicas financieras'}
# Ordinal {'002': 'Programa de seguros para el sector exportador', '004': 'Cubrimiento de costos no recuperables via tarifa o subsidio de la operación integral del servicio de aseo – departamento archipiélago de san andrés, providencia y santa catalina'}
# Ordinal {'001': 'Subvenciones a satena s.a. como único operador de rutas sociales. (art. 240 ley 1753 de 2015)'}
# Ordinal {'001': 'Transferencia de recursos al patrimonio autónomo fideicomiso de promoción de exportaciones - proexport. artículo 33 ley 1328 de 2009', '002': 'Transferencia fontur artículo 21 ley 1558 de 2012'}
# Objetos {3.0: 'Administración pública y defensa; planes de seguridad social de afiliación obligatoria', 6.0: 'Actividades de servicios financieros y de seguros', 1.0: 'Actividades de atención a la salud humana y de asistencia social', 2.0: 'Agricultura, ganadería, caza, silvicultura y pesca', 5.0: 'Educación', 7.0: 'Información y comunicaciones', 10.0: 'Distribución de agua; evacuación y tratamiento de aguas residuales, gestión de desechos y actividades de saneamiento ambiental', 9.0: 'Comercio al por mayor y al por menor; reparación de vehículos automotores y motocicletas', 8.0: 'Otras actividades de servicios'}
# Ordinal {'005': 'Transferencia a coljuegos', '001': 'Subsidio liquidaciones leyes 550 de 1999 y 1116 de 2006.'}
# Ordinal {'003': 'Transferencias  a fogafin, pasivos contingentes derivados de la venta de acciones banco popular y banco de colombia . art 31. ley 35 de 1993, decreto 2049 de 1993 y 1118  de 1995', '005': 'Cubrimiento del riesgo del deslizamiento del salario mínimo - decreto 036 de 2015', '004': 'Apertura y/u operación oficinas de la red social del banco agrario a nivel nacional. ley 795 de 2003'}
# Ordinal {'004': 'Financiación de beneficiarios del régimen subsidiado en salud. art.10 de la ley 1122 de 2017', '001': 'Campaña y control antituberculosis', '002': 'Plan nacional de salud rural', '003': 'Programa emergencia sanitaria', '005': 'Transferencia al instituto nacional de cancerología', '006': 'Transferencia al sanatorio de contratación', '007': 'Transferencia al sanatorio de agua de dios', '008': 'Transferencia al centro dermatológico federico lleras acosta', '009': 'apoyo a sostenimiento a residentes que cursen programas de especialización médico quirúrgica ley 1917 de 2018'}
# Ordinal {'001': 'Transferencias al sector agrícola y sector industrial para apoyo a la producción - artículo 1 ley 16 de 1990 y artículo 1 ley 101 de 1993; ley 795 de 2003'}
# Ordinal {'001': 'Fundación colegio mayor de san bartolomé (ley 72/83)'}
# Ordinal {'001': 'Transferir al operador oficial de los servicios de franquicia postal y telegráfica', '002': 'Transferencia  para financiamiento del servicio postal universal', '003': 'A radio televisión nacional de colombia (rtvc). articulo 45 ley 1978 de 2019'}
# Ordinal {'001': 'Transferencia a la corporación autónoma regional del río grande de la magdalena - cormagdalena'}
# Ordinal {'001': 'Transferencia a artesanías de colombia s.a.'}
# Ordinal {'002': 'Apoyo para el fomento al empleo', '001': 'Fortalecimiento organizacional de las entidades religiosas y las organizaciones basadas en la fe como actores sociales trascendentes en el marco de la ley 133 de 1994'}
# Objetos {1.0: 'A productores de mercado que distribuyen directamente a los hogares'}
# Ordinal {'001': 'Medidas de protección unp - blindaje arquitectónico - enfoque diferencial'}
# Objetos {1.0: 'A hogares diferentes de prestaciones sociales'}
# Ordinal {'001': 'Medidas de protección unp- apoyo de transporte, trasteo y de reubicación temporal'}
# Subcuentas {1.0: 'Impuestos', 4.0: 'Contribuciones', 3.0: 'Tasas y derechos administrativos', 5.0: 'Multas, sanciones e intereses de mora', 2.0: 'Estampillas'}
# Objetos {1.0: 'Cuota de fiscalización y auditaje', 3.0: 'Contribución nacional de valorización', 4.0: 'Contribución de valorización municipal', 7.0: 'Contribución de vigilancia – superintendencia nacional de salud', 2.0: 'Contribución - superintendencia financiera de colombia', 6.0: 'Contribución – superintendencia de vigilancia y seguridad privada'}
# Subcuentas {1.0: 'Principal', 2.0: 'Intereses', 3.0: 'Comisiones y otros gastos', 4.0: 'Fondo de contingencias'}
# Objetos {3.0: 'Otras cuentas por pagar', 1.0: 'Títulos de deuda', 2.0: 'Préstamos'}
# Objetos {1.0: 'Títulos de deuda', 2.0: 'Préstamos'}
# Objetos {1.0: 'Títulos de deuda'}
# Objetos {1.0: 'Aportes al fondo de contingencias'}
# Subcuentas {1000.0: 'Intersubsectorial gobierno'}
# Objetos {4.0: 'Desarrollo de estrategias para la socialización de la información legislativa del senado de la república  nacional'}
# Ordinal {'53105c': '5. convergencia regional / c. calidad, efectividad, transparencia y coherencia de las normas'}
# Subcuentas {1000.0: 'Intersubsectorial gobierno'}
# Objetos {11.0: 'Mejoramiento de las condiciones de seguridad y oportunidad en los desplazamientos de los servidores publicos del senado de la republica   nacional', 12.0: 'Fortalecimiento y modernización de los sistemas de información y de la infraestructura tecnológica del senado de la república   nacional', 13.0: 'Ampliación y actualización del sistema integrado de seguridad del congreso de la república  nacional', 14.0: 'Adecuación y mejoramiento de las instalaciones físicas del senado de la república  nacional', 15.0: 'Restauración de la imagen y funcionalidad de las sedes del senado de la república  nacional', 4.0: 'Mejoramiento del sistema de gestion documental y de la informacion en la camara de representantes bogota', 6.0: 'Fortalecimiento y renovación de los servicios de comunicación e información de la cámara de representantes  bogotá', 7.0: 'Mejoramiento de las condiciones de seguridad y proteccion en los desplazamientos de los servidores publicos de la camara de representantes nacional'}
# Ordinal {'53105b': '5. convergencia regional / b. entidades públicas territoriales y nacionales fortalecidas'}
# Ordinal {'53105b': '5. convergencia regional / b. entidades públicas territoriales y nacionales fortalecidas'}
# Ordinal {'53105b': '5. convergencia regional / b. entidades públicas territoriales y nacionales fortalecidas'}
# Ordinal {'53105b': '5. convergencia regional / b. entidades públicas territoriales y nacionales fortalecidas'}
# Ordinal {'53105b': '5. convergencia regional / b. entidades públicas territoriales y nacionales fortalecidas'}
# Ordinal {'53105b': '5. convergencia regional / b. entidades públicas territoriales y nacionales fortalecidas'}
# Ordinal {'53105b': '5. convergencia regional / b. entidades públicas territoriales y nacionales fortalecidas'}
# Ordinal {'53105b': '5. convergencia regional / b. entidades públicas territoriales y nacionales fortalecidas'}
# Subcuentas {1000.0: 'Intersubsectorial gobierno'}
# Objetos {7.0: 'Fortalecimiento en la articulación interinstitucional e intersectorial para la formulación e implementación de políticas públicas que contribuyen al goce efectivo de los derechos de los sujetos de especial protección. nacional', 9.0: 'Fortalecimiento de acciones para mejorar el acceso a la oferta en prevención de violencias, a través de estrategias de reconstrucción del tejido social y promoción de culturas de paz a nivel  nacional'}
# Ordinal {'70506c': '7. actores diferenciales para el cambio / c. instituciones hacia la interlocución con pueblos y comunidades'}
# Ordinal {'20106a': '2. seguridad humana y justicia social / a. prevención y protección para poblaciones vulnerables desde un enfoque diferencial, colectivo e individual'}
# Subcuentas {1000.0: 'Intersubsectorial gobierno'}
# Objetos {3.0: 'Contribucion para promover la sostenibilidad ambiental y socio-economica en municipios pdet y territorios afectados por el conflicto nacional', 16.0: 'Apoyo a la gestión financiera para el desarrollo de programas y proyectos para la implementación del acuerdo final de paz. nacional'}
# Ordinal {'600011': '6. paz total e integral / 1. hacia un nuevo campo colombiano: reforma rural integral'}
# Ordinal {'600014': '6. paz total e integral / 4. solución al problema de las drogas ilícitas'}
# Subcuentas {1000.0: 'Intersubsectorial gobierno'}
# Objetos {1.0: 'Fortalecimiento de las capacidades de gestión estratégica del sector público  nacional', 2.0: 'Consolidacion de la accion integral contra minas antipersonal a nivel  nacional', 3.0: 'Contribución para la implementación de estrategias en materia de políticas públicas de transparencia y corrupción a nivel  nacional'}
# Ordinal {'53105b': '5. convergencia regional / b. entidades públicas territoriales y nacionales fortalecidas'}
# Ordinal {'600030': '6. paz total e integral / 3. desescalamiento de la violencia'}
# Ordinal {'53105a': '5. convergencia regional / a. lucha contra la corrupción en las entidades públicas nacionales y territoriales'}
# Subcuentas {1000.0: 'Intersubsectorial gobierno'}
# Objetos {4.0: 'Fortalecimiento y protección de los bienes muebles e inmuebles de la presidencia de la república en  cartagena, bogotá, sopó', 5.0: 'Mejoramiento en la organización técnica del archivo central del dapre a nivel  bogotá', 6.0: 'Fortalecimiento de la plataforma de tic del departamento administrativo de la presidencia de la república en las sedes de   bogotá, cartagena, sopó', 1.0: 'Fortalecimiento de las herramientas tecnológicas para el cumplimiento y soporte de los lineamientos establecidos por el gobierno en materia de tecnologías de la información  nacional'}
# Ordinal {'53105b': '5. convergencia regional / b. entidades públicas territoriales y nacionales fortalecidas'}
# Ordinal {'53105b': '5. convergencia regional / b. entidades públicas territoriales y nacionales fortalecidas'}
# Ordinal {'53105b': '5. convergencia regional / b. entidades públicas territoriales y nacionales fortalecidas'}
# Ordinal {'53105b': '5. convergencia regional / b. entidades públicas territoriales y nacionales fortalecidas'}
# Subcuentas {1000.0: 'Intersubsectorial gobierno'}
# Objetos {12.0: 'Fortalecimiento  y articulación de actores e iniciativas de cooperación en el marco del sistema nacional de cooperación internacional a nivel  nacional', 13.0: 'Aportes para apalancar proyectos de cooperación internacional con recursos de contrapartida nacional desde apc -colombia, fortaleciendo actividades y resultados para comunidades y territorios estratégicos a nivel    nacional', 14.0: 'Distribución de cupo fiscal para facilitar la incorporación recursos de cooperación internacional al presupuesto general de la nación de entidades del orden  nacional - distribucion previo concepto dnp', 15.0: 'Administración , gestión y ejecución de los recursos de cooperación internacional que reciben los grupos de interés a nivel  nacional', 16.0: 'Fortalecimiento de las tic para la transformación digital de la agencia presidencial de cooperación internacional de colombia - apc colombia a nivel  nacional'}
# Ordinal {'53105b': '5. convergencia regional / b. entidades públicas territoriales y nacionales fortalecidas'}
# Ordinal {'803001': '8. estabilidad macroeconómica / 1. administración eficiente de los recursos públicos'}
# Ordinal {'803001': '8. estabilidad macroeconómica / 1. administración eficiente de los recursos públicos'}
# Ordinal {'803001': '8. estabilidad macroeconómica / 1. administración eficiente de los recursos públicos'}
# Ordinal {'53105b': '5. convergencia regional / b. entidades públicas territoriales y nacionales fortalecidas'}
# Subcuentas {1000.0: 'Intersubsectorial gobierno'}
# Objetos {6.0: 'Fortalecimiento de la gestión del riesgo de desastres en la  zona de amenaza volcá\x81nica alta-zava del volcá\x81n galeras  pasto, nariño, la florida', 12.0: 'Fortalecimiento de la política nacional de gestión del riesgo de desastres mediante la valoración del impacto de la implementación del pngrd.  nacional', 13.0: 'Fortalecimiento de los procesos sociales de participación ciudadana, gestión de conocimientos y saberes y divulgación en el marco del  sistema nacional de gestión del riesgo de desastre.  nacional'}
# Ordinal {'10201b': '1. ordenamiento del territorio alrededor del agua y justicia ambiental / b. democratización del conocimiento, la información ambiental y de riesgo de desastres'}
# Ordinal {'10201b': '1. ordenamiento del territorio alrededor del agua y justicia ambiental / b. democratización del conocimiento, la información ambiental y de riesgo de desastres'}
# Ordinal {'10201b': '1. ordenamiento del territorio alrededor del agua y justicia ambiental / b. democratización del conocimiento, la información ambiental y de riesgo de desastres'}
# Subcuentas {1000.0: 'Intersubsectorial gobierno'}
# Objetos {3.0: 'Prevención riesgos de victimización y reincidencia en población en proceso de reintegración y en reincorporación  nacional', 4.0: 'Fortalecimiento de la reincorporación de los exintegrantes de las farc-ep  nacional'}
# Ordinal {'53107c': '5. convergencia regional / c. inclusión de las personas que han dejado las armas y potenciar su participación en las comunidades y territorios donde habitan _'}
# Ordinal {'53107c': '5. convergencia regional / c. inclusión de las personas que han dejado las armas y potenciar su participación en las comunidades y territorios donde habitan _'}
# Subcuentas {1000.0: 'Intersubsectorial gobierno'}
# Objetos {3.0: 'Renovación urbana ciudad can  bogotá', 4.0: 'Desarrollo y formulación de proyectos estratégicos de renovación y desarrollo urbano en municipios y distritos de colombia  nacional'}
# Ordinal {'51101b': '5. convergencia regional / b. revitalización en los procesos de transformación y aprovechamiento de la ciudad construida'}
# Ordinal {'51101b': '5. convergencia regional / b. revitalización en los procesos de transformación y aprovechamiento de la ciudad construida'}
# Subcuentas {1000.0: 'Intersubsectorial gobierno'}
# Objetos {10.0: 'Apoyo a la implementacion y financiacion de los programas de desarrollo con enfoque territorial - pdet en los territorios priorizados a nivel  nacional', 11.0: 'Optimizacion de la medicion del avance en la implementacion de los pdet  nacional', 12.0: 'Contribución al cierre de brechas a través de la implementación de proyectos para la transformación y la vida en los territorios pdet  nacional'}
# Ordinal {'51202j': '5. convergencia regional / j. integración de los territorios más afectados por el conflicto a las apuestas estratégicas de desarrollo regional de acuerdo con la reforma rural integral'}
# Ordinal {'51202j': '5. convergencia regional / j. integración de los territorios más afectados por el conflicto a las apuestas estratégicas de desarrollo regional de acuerdo con la reforma rural integral'}
# Ordinal {'51202j': '5. convergencia regional / j. integración de los territorios más afectados por el conflicto a las apuestas estratégicas de desarrollo regional de acuerdo con la reforma rural integral'}
# Subcuentas {1000.0: 'Intersubsectorial gobierno'}
# Objetos {18.0: 'Apoyo al desarrollo de proyectos a través del fondo regional para los contratos plan.  nacional', 20.0: 'Fortalecimiento de las entidades territoriales   nacional', 22.0: 'Implementación del sistema nacional catastral multipropósito desde el dnp alcance  nacional', 29.0: 'Fortalecimiento de politicas y acciones de logistica  nacional', 30.0: 'Consolidacion esquemas para promover la participacion privada en el desarrollo de infraestructura publica y prestacion de sus servicios asociados   nacional', 31.0: 'Apoyo presupuestal a entidades pertenecientes al presupuesto general de la nacion en la implementacion de proyectos de inversión a nivel  nacional-[distribucion previo concepto dnp]', 33.0: 'Fortalecimiento del ciclo de las politicas publicas sectoriales e intersectoriales para el desarrollo  nacional', 34.0: 'Mejoramiento de los resultados de la gestion publica territorial a nivel   nacional', 35.0: 'Modernizacion de la vision de largo plazo en la planeacion intersectorial a nivel  nacional', 38.0: 'Aprovechamiento de la información del seguimiento y la evaluación de políticas públicas para la toma de decisiones basadas en evidencia, a nivel nacional', 39.0: 'Diseño e implementación del registro social como instrumento de orientación y/o focalización de gasto social a nivel  nacional', 40.0: 'Fortalecimiento de la gestión de la inversión pública a nivel territorial y  nacional'}
# Ordinal {'51102e': '5. convergencia regional / e. planeación y gestión territorial inteligente'}
# Ordinal {'51102e': '5. convergencia regional / e. planeación y gestión territorial inteligente'}
# Ordinal {'10305b': '1. ordenamiento del territorio alrededor del agua y justicia ambiental / b. actualización catastral multipropósito'}
# Ordinal {'52104e': '5. convergencia regional / e. infraestructura y servicios logísticos'}
# Ordinal {'52104e': '5. convergencia regional / e. infraestructura y servicios logísticos'}
# Ordinal {'53105b': '5. convergencia regional / b. entidades públicas territoriales y nacionales fortalecidas'}
# Ordinal {'53105f': '5. convergencia regional / f. eficiencia institucional para el cumplimiento de los acuerdos realizados con las comunidades'}
# Ordinal {'53105b': '5. convergencia regional / b. entidades públicas territoriales y nacionales fortalecidas'}
# Ordinal {'53105f': '5. convergencia regional / f. eficiencia institucional para el cumplimiento de los acuerdos realizados con las comunidades'}
# Ordinal {'53105f': '5. convergencia regional / f. eficiencia institucional para el cumplimiento de los acuerdos realizados con las comunidades'}
# Ordinal {'53105f': '5. convergencia regional / f. eficiencia institucional para el cumplimiento de los acuerdos realizados con las comunidades'}
# Ordinal {'803001': '8. estabilidad macroeconómica / 1. administración eficiente de los recursos públicos'}
# Subcuentas {1000.0: 'Intersubsectorial gobierno'}
# Objetos {7.0: 'Fortalecimiento  de los espacios fisicos en las sedes de la superintendencia de servicios publicos domiciliarios a nivel  nacional', 8.0: 'Fortalecimiento de las tic para el cumplimiento de los objetivos del dnp a nivel nacional', 9.0: 'Fortalecimiento institucional de la planeación, gestión y evaluación del dnp a nivel  nacional', 6.0: 'Fortalecimiento del modelo de arquitectura empresarial en la superintendencia de servicios publicos domiciliarios a nivel  nacional'}
# Ordinal {'53105b': '5. convergencia regional / b. entidades públicas territoriales y nacionales fortalecidas'}
# Ordinal {'53105b': '5. convergencia regional / b. entidades públicas territoriales y nacionales fortalecidas'}
# Ordinal {'53105b': '5. convergencia regional / b. entidades públicas territoriales y nacionales fortalecidas'}
# Ordinal {'53105b': '5. convergencia regional / b. entidades públicas territoriales y nacionales fortalecidas'}
# Subcuentas {1000.0: 'Intersubsectorial gobierno'}
# Objetos {3.0: 'Generación efectividad y transparencia en las plataformas de compra pública nacional', 4.0: 'Generación de principales insumos para democratizar la compra pública  nacional'}
# Ordinal {'53105a': '5. convergencia regional / a. lucha contra la corrupción en las entidades públicas nacionales y territoriales'}
# Ordinal {'20307b': '2. seguridad humana y justicia social / b. sostenibilidad y crecimiento de las unidades económicas y formas de asociatividad de la ep'}
# Subcuentas {1000.0: 'Intersubsectorial gobierno'}
# Objetos {19.0: 'Fortalecimiento de la inspeccion, vigilancia y control a los prestadores de servicios publicos domiciliarios en materia atencion y proteccion al usuario   nacional', 20.0: 'Innovacion en el modelo de vigilancia de los prestadores de los servicios publicos de energia electrica y gas combustible. nacional', 21.0: 'Fortalecimiento de la gobernanza de las tecnologias de la informacion en el cumplimiento de la misionalidad de la superservicios a nivel  nacional', 22.0: 'Implementación de las acciones de inspección, vigilancia y control (ivc) diferencial para las organizaciones comunitarias de servicios de agua y saneamiento básico (ocsas) a nivel  nacional', 23.0: 'Optimización de las acciones de inspección, control y vigilancia de la calidad del agua suministrada a los usuarios del servicio de acueducto a nivel   nacional', 24.0: 'Fortalecimiento de las acciones de inspección, vigilancia y control hacia los prestadores del servicio de alcantarillado a nivel  nacional'}
# Ordinal {'53105a': '5. convergencia regional / a. lucha contra la corrupción en las entidades públicas nacionales y territoriales'}
# Ordinal {'53105a': '5. convergencia regional / a. lucha contra la corrupción en las entidades públicas nacionales y territoriales'}
# Ordinal {'53105b': '5. convergencia regional / b. entidades públicas territoriales y nacionales fortalecidas'}
# Ordinal {'53105a': '5. convergencia regional / a. lucha contra la corrupción en las entidades públicas nacionales y territoriales'}
# Ordinal {'53105a': '5. convergencia regional / a. lucha contra la corrupción en las entidades públicas nacionales y territoriales'}
# Ordinal {'53105a': '5. convergencia regional / a. lucha contra la corrupción en las entidades públicas nacionales y territoriales'}
# Subcuentas {1003.0: 'Planificación y estadística'}
# Objetos {30.0: 'Consolidacion de una cultura estadistica a traves de la informacion como un bien publico del pais  nacional', 31.0: 'Fortalecimiento de la producción de información estadística analizada  nacional', 32.0: 'Fortalecimiento de la integración de la información geoespacial en el proceso estadístico nacional  nacional', 33.0: 'Ampliación de la capacidad del dane para la coordinación del sistema estadístico nacional - sen nacional  nacional', 34.0: 'Producción de información estructural.  nacional', 35.0: 'Optimización de la capacidad del dane en sus procesos de recolección y acopio de la información estadística oficial. nacional', 36.0: 'Fortalecimiento de las capacidades institucionales de prospectiva e innovación en la producción de estadísticas oficiales a nivel   nacional', 3.0: 'Fortalecimiento de la capacidad de producción de información estadística del sen.  nacional'}
# Ordinal {'20104d': '2. seguridad humana y justicia social / d. datos sectoriales para aumentar el aprovechamiento de datos en el país'}
# Ordinal {'20104d': '2. seguridad humana y justicia social / d. datos sectoriales para aumentar el aprovechamiento de datos en el país'}
# Ordinal {'20104d': '2. seguridad humana y justicia social / d. datos sectoriales para aumentar el aprovechamiento de datos en el país'}
# Ordinal {'20104d': '2. seguridad humana y justicia social / d. datos sectoriales para aumentar el aprovechamiento de datos en el país'}
# Ordinal {'20104d': '2. seguridad humana y justicia social / d. datos sectoriales para aumentar el aprovechamiento de datos en el país'}
# Ordinal {'20104d': '2. seguridad humana y justicia social / d. datos sectoriales para aumentar el aprovechamiento de datos en el país'}
# Ordinal {'20104d': '2. seguridad humana y justicia social / d. datos sectoriales para aumentar el aprovechamiento de datos en el país'}
# Ordinal {'20104d': '2. seguridad humana y justicia social / d. datos sectoriales para aumentar el aprovechamiento de datos en el país'}
# Subcuentas {1003.0: 'Planificación y estadística'}
# Objetos {7.0: 'Mejoramiento  de la infraestructura y equipamiento físico de la entidad a nivel   nacional', 8.0: 'Modernización de la gestión documental del dane nacional', 9.0: 'Fortalecimiento del modelo de operación institucional del igac a nivel  nacional', 10.0: 'Modernización tecnológica para la transformación digital del dane a nivel nacional'}
# Ordinal {'53105b': '5. convergencia regional / b. entidades públicas territoriales y nacionales fortalecidas'}
# Ordinal {'53105b': '5. convergencia regional / b. entidades públicas territoriales y nacionales fortalecidas'}
# Ordinal {'53105b': '5. convergencia regional / b. entidades públicas territoriales y nacionales fortalecidas'}
# Ordinal {'53105b': '5. convergencia regional / b. entidades públicas territoriales y nacionales fortalecidas'}
# Subcuentas {1003.0: 'Planificación y estadística'}
# Objetos {2.0: 'Actualización  y gestión catastral  nacional'}
# Ordinal {'10305b': '1. ordenamiento del territorio alrededor del agua y justicia ambiental / b. actualización catastral multipropósito'}
# Subcuentas {1003.0: 'Planificación y estadística'}
# Objetos {1.0: 'Levantamiento generacion  y actualizacion de la red geodesica nacional y la cartografia  del pais como herramienta fundamental para el establecimiento de politicas de desarrollo   nacional', 2.0: 'Fortalecimiento de la gestion del conocimiento y la innovacion en el ambito geografico del territorio  nacional', 3.0: 'Desarrollo de estudios de suelos, tierras y aplicaciones agrologicas como insumo para el ordenamiento integral y el manejo sostenible del territorio.  nacional', 4.0: 'Generacion de estudios geograficos e investigaciones para la caracterizacion, analisis y delimitacion geografica del territorio nacional  nacional'}
# Ordinal {'10305b': '1. ordenamiento del territorio alrededor del agua y justicia ambiental / b. actualización catastral multipropósito'}
# Ordinal {'10305b': '1. ordenamiento del territorio alrededor del agua y justicia ambiental / b. actualización catastral multipropósito'}
# Ordinal {'10305b': '1. ordenamiento del territorio alrededor del agua y justicia ambiental / b. actualización catastral multipropósito'}
# Ordinal {'10305b': '1. ordenamiento del territorio alrededor del agua y justicia ambiental / b. actualización catastral multipropósito'}
# Subcuentas {1000.0: 'Intersubsectorial gobierno'}
# Objetos {5.0: 'Formulación consolidación de las capacidades de gestión y desempeño de las entidades y servidores públicos del nivel territorial y nacional para recuperar la confianza de la ciudadanía en el estado -  nacional  nacional', 6.0: 'Formulación fortalecimiento de las capacidades institucionales para la prestación optima de un servicio público de calidad a las ciudadanías  bogotá', 3.0: 'Mejoramiento de estrategias de fortalecimiento del alto gobierno y la alta gerencia publica territorial y  nacional', 4.0: 'Fortalecimiento y apoyo a la gestion de las entidades estatales, la capacitacion y los procesos de seleccion  nacional'}
# Ordinal {'53105b': '5. convergencia regional / b. entidades públicas territoriales y nacionales fortalecidas'}
# Ordinal {'53105b': '5. convergencia regional / b. entidades públicas territoriales y nacionales fortalecidas'}
# Ordinal {'20306d': '2. seguridad humana y justicia social / d. modernización y transformación del empleo público'}
# Ordinal {'20306d': '2. seguridad humana y justicia social / d. modernización y transformación del empleo público'}
# Subcuentas {1000.0: 'Intersubsectorial gobierno'}
# Objetos {7.0: 'Transformación de las administraciones públicas  mediante el desarrollo de políticas y lineamientos que permitan el fortalecimiento de los componentes de la función administrativa, la función pública y la gestión pública  nacional', 8.0: 'Mejoramiento de las tecnologías de la información y las comunicaciones a nivel institucional para dar cumplimiento a las políticas de gobierno digital y transformación digital  bogotá', 4.0: 'Fortalecimiento de la infraestructura fisica y tecnologica de la esap a nivel  nacional', 5.0: 'Mejoramiento de la capacidad y desempeno institucional de los procesos administrativos en la escuela superior de administracion publica para el desarrollo de su misionalidad.  nacional', 3.0: 'Fortalecimiento de las capacidades institucionales para la mejora de la gestión integral de la cnsc - comisión  nacional'}
# Ordinal {'53105b': '5. convergencia regional / b. entidades públicas territoriales y nacionales fortalecidas'}
# Ordinal {'53105b': '5. convergencia regional / b. entidades públicas territoriales y nacionales fortalecidas'}
# Ordinal {'20203k': '2. seguridad humana y justicia social / k. educación superior como un derecho'}
# Ordinal {'53105b': '5. convergencia regional / b. entidades públicas territoriales y nacionales fortalecidas'}
# Ordinal {' 53105b ': '5. convergencia regional / b. entidades públicas territoriales y nacionales fortalecidas'}
# Subcuentas {1000.0: 'Intersubsectorial gobierno'}
# Objetos {16.0: 'Fortalecimiento de la capacidad institucional para el aseguramiento de la calidad academica de los programas de pregrado y posgrado de la esap   nacional', 17.0: 'Fortalecimiento de la investigacion e innovacion en la administracion publica  de la esap  nacional', 18.0: 'Fortalecimiento del reconocimiento  internacional de la esap como referente en la formacion y asesoria del saber administrativo publico  nacional'}
# Ordinal {'20203k': '2. seguridad humana y justicia social / k. educación superior como un derecho'}
# Ordinal {'40402a': '4. transformación productiva, internacionalización y acción clímatica / a. concurrencia de recursos alrededor de inversiones estratégicas en ciencia, tecnología e innovación (cti)'}
# Ordinal {'20109g': '2. seguridad humana y justicia social / g. modernización para incrementar el valor público, la integridad y la transparencia en la seguridad'}
# Subcuentas {1002.0: 'Relaciones exteriores'}
# ...
# Ordinal {' 20101a ': '2. seguridad humana y justicia social / a. sistema de transferencias y programa renta ciudadana'}
# Ordinal {'53105b': '5. convergencia regional / b. entidades públicas territoriales y nacionales fortalecidas'}
# Subcuentas {1500.0: 'Intersubsectorial desarrollo social'}
# Objetos {3.0: 'Fortalecimiento de las tecnologías de información y comunicaciones en prosperidad social dps a nivel nacional  nacional', 4.0: 'Ampliacion de la capacidad tecnologica, uso y gestion de la informacion orientada a la transformacion digital para la atencion y reparacion integral a las victimas a nivel nacional', 5.0: 'Fortalecimiento  a la planeacion, operacion y seguimiento de la gestion institucional en la unidad para la atencion y reparacion integral a las victimas a nivel nacional  nacional', 2.0: 'Consolidacion de la plataforma tecnologica para la adecuada gestion de la informacion del centro nacional de memoria historica a nivel   nacional'}
# Ordinal {' 53105b ': '5. convergencia regional / b. entidades públicas territoriales y nacionales fortalecidas'}
# Ordinal {' 53105d ': '5. convergencia regional / d. gobierno digital para la gente'}
# Ordinal {' 53105b ': '5. convergencia regional / b. entidades públicas territoriales y nacionales fortalecidas'}
# Ordinal {' 53105b ': '5. convergencia regional / b. entidades públicas territoriales y nacionales fortalecidas'}
# Subcuentas {1500.0: 'Intersubsectorial desarrollo social'}
# Objetos {23.0: 'Mejoramiento de la informacion del registro unico de victimas   nacional', 24.0: 'Implementacion de los procesos de retornos, reubicacion e integracion local de los hogares y comunidades victimas del desplazamiento forzado en colombia.   nacional', 25.0: 'Fortalecimiento de los canales de atencion y orientacion a las victimas del conflicto armado a nivel nacional  nacional', 26.0: 'Fortalecimiento de la articulacion del sistema nacional de atencion y reparacion integral de las victimas- snariv durante la implementacion de la ppv  nacional', 27.0: 'Fortalecimiento de las medidas de prevencion y asistencia para la poblacion victima a nivel  nacional', 28.0: 'Implementacion de las medidas de reparacion en las victimas del conflicto armado a nivel  nacional', 29.0: 'Fortalecimiento en la implementación de la política pública de atención, asistencia y reparación integral de las víctimas pertenecientes a los pueblos y comunidades étnicas a nivel  nacional', 15.0: 'Divulgacion de acciones de memoria historica a nivel nacional  nacional', 16.0: 'Implementacion de las acciones de memoria historica a nivel   nacional', 17.0: 'Fortalecimiento de procesos de memoria historica a nivel  nacional', 18.0: 'Implementacion de acciones del museo de memoria a nivel  nacional', 19.0: 'Consolidacion del archivo de los derechos humanos, memoria historica y conflicto armado y colecciones de derechos humanos y derecho internacional humanitario.  nacional'}
# Ordinal {' 53107b ': '5. convergencia regional / b. acceso efectivo de las víctimas del conflicto armado a las medidas de reparación integral'}
# Ordinal {' 53107b ': '5. convergencia regional / b. acceso efectivo de las víctimas del conflicto armado a las medidas de reparación integral'}
# Ordinal {' 53107b ': '5. convergencia regional / b. acceso efectivo de las víctimas del conflicto armado a las medidas de reparación integral'}
# Ordinal {' 20101i ': '2. seguridad humana y justicia social / i. superación de situación de vulnerabilidad para la reparación efectiva e integral de la población víctima del conflicto', '20113e': '2. seguridad humana y justicia social / e. ciudadanías activas y participativas que construyen paz y justicia social', ' 53107b ': '5. convergencia regional / b. acceso efectivo de las víctimas del conflicto armado a las medidas de reparación integral'}
# Ordinal {' 53107b ': '5. convergencia regional / b. acceso efectivo de las víctimas del conflicto armado a las medidas de reparación integral'}
# Ordinal {' 53107b ': '5. convergencia regional / b. acceso efectivo de las víctimas del conflicto armado a las medidas de reparación integral'}
# Ordinal {' 53107b ': '5. convergencia regional / b. acceso efectivo de las víctimas del conflicto armado a las medidas de reparación integral'}
# Ordinal {' 53107a ': '5. convergencia regional / a. diálogo, memoria, convivencia y reconciliación para la reconstrucción del tejido social'}
# Ordinal {' 53107a ': '5. convergencia regional / a. diálogo, memoria, convivencia y reconciliación para la reconstrucción del tejido social'}
# Ordinal {' 53107a ': '5. convergencia regional / a. diálogo, memoria, convivencia y reconciliación para la reconstrucción del tejido social'}
# Ordinal {' 53107a ': '5. convergencia regional / a. diálogo, memoria, convivencia y reconciliación para la reconstrucción del tejido social'}
# Ordinal {' 53107a ': '5. convergencia regional / a. diálogo, memoria, convivencia y reconciliación para la reconstrucción del tejido social'}
# Subcuentas {100.0: 'Intersubsectorial defensa y seguridad'}
# Objetos {5.0: 'Consolidación de los servicios de formación de inteligencia estratégica y contrainteligencia de estado a nivel  nacional', 6.0: 'Construcción sede operacional de la dni a nivel  nacional', 7.0: 'Actualización de los servicios de tecnologías de la información y de las comunicaciones en materia de inteligencia estratégica a nivel   nacional'}
# Ordinal {' 20107d ': '2. seguridad humana y justicia social / d. inteligencia estratégica más efectiva, transparente y al servicio de la protección de la vida, derechos y libertades'}
# Ordinal {' 20107d ': '2. seguridad humana y justicia social / d. inteligencia estratégica más efectiva, transparente y al servicio de la protección de la vida, derechos y libertades'}
# Ordinal {' 20107d ': '2. seguridad humana y justicia social / d. inteligencia estratégica más efectiva, transparente y al servicio de la protección de la vida, derechos y libertades'}
# Subcuentas {1604.0: 'Recreación y deporte'}
# Objetos {13.0: 'Fortalecimiento fortalecimiento del deporte y la educacion fisica de los ninos, ninas y adolescentes en etapa escolar  nacional', 14.0: 'Fortalecimiento fomento y promocion de la practica deportiva, recreativa y de actividad fisica en colombia  nacional'}
# Ordinal {' 20203b ': '2. seguridad humana y justicia social / b. resignificación de la jornada escolar: más que tiempo'}
# Ordinal {' 20303a ': '2. seguridad humana y justicia social / a. democratizar el acceso de la población al deporte, la recreación y la actividad física'}
# Subcuentas {1604.0: 'Recreación y deporte'}
# Objetos {23.0: 'Apoyo a la inspección, vigilancia y control a nivel   nacional', 24.0: 'Apoyo  al programa al control dopaje   nacional', 26.0: 'Desarrollo del deporte olimpico, paralimpico y nivel mundial para el posicionamiento y liderazgo deportivo  nacional', 27.0: 'Fortalecimiento del laboratorio de control al dopaje deportivo  nacional', 28.0: 'Apoyo de la infraestructura deportiva, recreativa y de alta competencia en colombia.  nacional', 29.0: 'Apoyo en el desarrollo de juegos y eventos deportivos de rendimiento y alto rendimiento en colombia  nacional'}
# Ordinal {' 20303a ': '2. seguridad humana y justicia social / a. democratizar el acceso de la población al deporte, la recreación y la actividad física'}
# Ordinal {' 20303e ': '2. seguridad humana y justicia social / e. atletas y paratletas como embajadores de paz en el mundo'}
# Ordinal {' 20303e ': '2. seguridad humana y justicia social / e. atletas y paratletas como embajadores de paz en el mundo'}
# Ordinal {' 20303e ': '2. seguridad humana y justicia social / e. atletas y paratletas como embajadores de paz en el mundo'}
# Ordinal {' 20303a ': '2. seguridad humana y justicia social / a. democratizar el acceso de la población al deporte, la recreación y la actividad física'}
# Ordinal {' 20303f ': '2. seguridad humana y justicia social / f. el deporte, la recreación y la actividad física como eje de la economía popular'}
# Subcuentas {1604.0: 'Recreación y deporte'}
# Objetos {8.0: 'Mejoramiento sedes coldeportes  bogotá', 10.0: 'Fortalecimiento de la gestión y seguimiento institucional del ministerio del deporte  nacional'}
# Ordinal {' 53105b ': '5. convergencia regional / b. entidades públicas territoriales y nacionales fortalecidas'}
# Ordinal {' 53105b ': '5. convergencia regional / b. entidades públicas territoriales y nacionales fortalecidas'}
# Subcuentas {1000.0: 'Intersubsectorial gobierno'}
# Objetos {5.0: 'Fortalecimiento de la investigacion y acusacion y el ejercicio de la accion penal de la uia de la jep a nivel nacional nacional', 6.0: 'Fortalecimiento de las herramientas y estrategias con enfoques diferenciales para la participacion efectiva en la justicia transicional y restaurativa. nacional', 7.0: 'Fortalecimiento  de las medidas de provención (prevención y protección) a los titulares de derecho de la jep a nivel nacional  nacional'}
# Ordinal {'20113c': '2. seguridad humana y justicia social / c. implementación del sistema restaurativo de la jurisdicción especial para la paz'}
# Ordinal {'20113c': '2. seguridad humana y justicia social / c. implementación del sistema restaurativo de la jurisdicción especial para la paz'}
# Ordinal {'20113c': '2. seguridad humana y justicia social / c. implementación del sistema restaurativo de la jurisdicción especial para la paz'}
# Subcuentas {1000.0: 'Intersubsectorial gobierno'}
# Objetos {3.0: 'Adecuación dotación y puesta en funcionamiento de las sedes de la jurisdicción especial para la paz  nacional', 5.0: 'Fortalecimiento de la capacidad de apoyo de la arquitectura de soluciones tecnologicas al desarrollo evolutivo de la entidad bogota', 6.0: 'Fortalecimiento a la implementación de herramientas para la gestión estratégica y administrativa de la jurisdicción especial para la paz  bogotá', 1.0: 'Fortalecimiento de la unidad de busqueda de personas dadas por desaparecidas  nacional', 2.0: 'Fortalecimiento de las capacidades tecnológicas de la unidad de búsqueda de personas dadas por desaparecidas nacional'}
# Ordinal {' 53105b ': '5. convergencia regional / b. entidades públicas territoriales y nacionales fortalecidas'}
# Ordinal {' 53105d ': '5. convergencia regional / d. gobierno digital para la gente'}
# Ordinal {' 53105b ': '5. convergencia regional / b. entidades públicas territoriales y nacionales fortalecidas'}
# Ordinal {' 53105b ': '5. convergencia regional / b. entidades públicas territoriales y nacionales fortalecidas'}
# Ordinal {' 53105b ': '5. convergencia regional / b. entidades públicas territoriales y nacionales fortalecidas'}
# Subcuentas {1000.0: 'Intersubsectorial gobierno'}
# Objetos {2.0: 'Implementación de acciones humanitarias y extrajudiciales de búsqueda de personas dadas por desaparecidas en razón y en contexto del conflicto armado colombiano nacional'}
# Ordinal {'20113a': '2. seguridad humana y justicia social / a. fortalecimiento de la búsqueda de personas dadas por desaparecidas'}
# Subcuentas {1500.0: 'Intersubsectorial desarrollo social'}
# Objetos {1.0: 'Fortalecimiento de las acciones que garanticen el goce efectivo del derecho a la igualdad de los sujetos de especial protección a nivel  nacional'}
# Ordinal {702020: '7. actores diferenciales para el cambio / 2. construcción de tejido social diverso, con garantía de derechos y sin discriminación'}
# Subcuentas {1500.0: 'Intersubsectorial desarrollo social'}
# Objetos {1.0: 'Protección de los niños, niñas y adolescentes en el marco del restablecimiento de sus derechos a nivel   nacional', 2.0: 'Fortalecimiento de acciones de restablecimiento en administración de justicia a nivel   nacional', 3.0: 'Fortalecimiento a los agentes e instancias del snbf en el marco de la protección integral de los niños, niñas y adolescentes y sus familias a nivel   nacional', 5.0: 'Contribución con acciones de promoción y prevención en el componente de alimentación y nutrición para la población colombiana a nivel nacional', 6.0: 'Apoyo al desarrollo integral de la primera infancia a nivel  nacional', 7.0: 'Contribucion al desarrollo integral de ninas y ninos entre 6-13 anos, en el marco del reconocimiento, garantia de sus derechos y construccion de proyectos de vida a nivel   nacional', 8.0: 'Apoyo para el desarrollo de los proyectos de vida para adolescentes y jovenes a nivel   nacional', 9.0: 'Fortalecimiento de capacidades y disposición de condiciones y oportunidades que promuevan el desarrollo integral de las niñas, niños, adolescentes, familias y comunidades a nivel  nacional', 10.0: 'Fortalecimiento de capacidades individuales, familiares e institucionales para prevenir y atender la materialización del riesgo, la amenaza y/o vulneración de los derechos de los niñas, niños adolescentes y jóvenes  nacional'}
# Ordinal {704060: '7. actores diferenciales para el cambio / 6. creación del sistema nacional de justicia familiar para atender las vulneraciones de derechos que afectan a las niñas, niños y adolescentes'}
# Ordinal {704060: '7. actores diferenciales para el cambio / 6. creación del sistema nacional de justicia familiar para atender las vulneraciones de derechos que afectan a las niñas, niños y adolescentes'}
# Ordinal {704050: '7. actores diferenciales para el cambio / 5. consolidación del sistema nacional de bienestar familiar y del gasto público para la niñez'}
# Ordinal {' 30205b ': '3. derecho humano a la alimentación / b. entornos de desarrollo que incentiven la alimentación saludable y adecuada'}
# Ordinal {704020: '7. actores diferenciales para el cambio / 2. universalización de la atención integral a la primera infancia en los territorios con mayor riesgo de vulneración de derechos para la niñez'}
# Ordinal {704030: '7. actores diferenciales para el cambio / 3. protección de la trayectoria de vida y educativas a través del arte, deporte, cultura, ambiente y ciencia y tecnología'}
# Ordinal {704030: '7. actores diferenciales para el cambio / 3. protección de la trayectoria de vida y educativas a través del arte, deporte, cultura, ambiente y ciencia y tecnología'}
# Ordinal {704020: '7. actores diferenciales para el cambio / 2. universalización de la atención integral a la primera infancia en los territorios con mayor riesgo de vulneración de derechos para la niñez', 704080: '7. actores diferenciales para el cambio / 8. el instituto colombiano de bienestar familiar como impulsor de proyectos de vida'}
# Ordinal {704040: '7. actores diferenciales para el cambio / 4. fortalecimiento de las familias y las comunidades'}
# Subcuentas {1500.0: 'Intersubsectorial desarrollo social'}
# Objetos {1.0: 'Fortalecimiento de la gestión institucional del insor para la consecución de objetivos  nacional', 2.0: 'Optimización de las capacidades institucionales para fortalecer la gestión de los procesos a nivel  nacional'}
# Ordinal {704080: '7. actores diferenciales para el cambio / 8. el instituto colombiano de bienestar familiar como impulsor de proyectos de vida', 707010: '7. actores diferenciales para el cambio / 1. una gobernanza sólida para potenciar la garantía de derechos de la población con discapacidad'}
# Ordinal {' 53105b ': '5. convergencia regional / b. entidades públicas territoriales y nacionales fortalecidas', 707010: '7. actores diferenciales para el cambio / 1. una gobernanza sólida para potenciar la garantía de derechos de la población con discapacidad'}
# Subcuentas {1500.0: 'Intersubsectorial desarrollo social'}
# Objetos {1.0: 'Mejoramiento de herramientas y orientaciones para el acceso al goce efectivo de derechos de la población sorda  nacional', 2.0: 'Mejoramiento de los procesos de atención para el beneficio de las personas con discapacidad visual a nivel   nacional'}
# Ordinal {707010: '7. actores diferenciales para el cambio / 1. una gobernanza sólida para potenciar la garantía de derechos de la población con discapacidad'}
# Ordinal {707010: '7. actores diferenciales para el cambio / 1. una gobernanza sólida para potenciar la garantía de derechos de la población con discapacidad'}
